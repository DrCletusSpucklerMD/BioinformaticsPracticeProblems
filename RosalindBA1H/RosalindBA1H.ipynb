# %%
pattern = 'CTCACTCCAGCG'
text = '...'
d = 6

# %%
def hamming_distance(string1, string2):
    distance = 0
    for i in range(len(string1)):
        if string1[i] != string2[i]:
            distance += 1
    return distance

# %%
def approx_pattern_match(pattern, text, d):
    count = 0
    starting_pos = []
    for i in range(len(text) - len(pattern) + 1):
        pattern_ = text[i:(i+len(pattern))]
        if hamming_distance(pattern, pattern_) <= d:
            count += 1
            starting_pos.append(i)
    return print(*starting_pos)

# %%
approx_pattern_match(pattern, text, d)
# Out:
# 1 3 5 82 157 165 169 171 173 196 198 213 250 285 299 328 330 352 359 363 373 375 377 392 395 400 420 422 424 439 441 452 480 489 491 495 500 509 519 523 532 583 627 632 662 668 683 743 782 829 835 840 842 903 915 920 924 948 959 980 1005 1009 1021 1053 1057 1078 1080 1082 1086 1090 1106 1152 1177 1197 1200 1218 1266 1276 1299 1304 1365 1377 1401 1404 1418 1420 1442 1467 1471 1504 1506 1508 1518 1539 1559 1566 1590 1591 1659 1663 1666 1676 1683 1718 1739 1743 1761 1778 1805 1811 1813 1815 1850 1885 1889 1894 1915 1923 1958 1961 1970 1991 1995 1999 2034 2044 2070 2077 2092 2096 2098 2139 2149 2151 2153 2155 2157 2167 2228 2240 2269 2282 2311 2317 2341 2346 2370 2374 2376 2386 2398 2436 2452 2454 2462 2466 2496 2529 2549 2559 2562 2566 2595 2597 2600 2608 2613 2647 2649 2659 2664 2665 2697 2705 2710 2714 2754 2760 2763 2774 2786 2789 2799 2867 2937 2954 2957 2982 2998 3000 3008 3053 3097 3116 3120 3149 3167 3177 3194 3202 3247 3252 3255 3259 3263 3296 3298 3318 3326 3351 3353 3380 3387 
# ...
